# %% [markdown]
# ## 2. Initial Data Exploration

# %%
# Task 2.1
import pandas as pd

# Load the dataset
df = pd.read_csv('cafe_sales.csv')

# Display the shape
print(df.shape)

# %%
# Display Data Types
print(df.dtypes)
# Out:
# Transaction ID      str
# Item                str
# Quantity            str
# Price Per Unit      str
# Total Spent         str
# Payment Method      str
# Location            str
# Transaction Date    str
# dtype: object

# %%
# Display All Missing Data
print(df.isnull().all())

# %%
# Display Summary Data
df.describe()
# Out:
#        Transaction ID   Item Quantity Price Per Unit Total Spent  \
# count           10000   9667     9862           9821        9827
# unique          10000     10        7              8          19
# top       TXN_1961373  Juice        5            3.0         6.0
# freq                1   1171     2013           2429         979
#
#         Payment Method  Location Transaction Date
# count             7421      6735             9841
# unique               5         4              367
# top     Digital Wallet  Takeaway          UNKNOWN
# freq              2291      3022              159

# %%
# Task 2.2
# Missing data in a columns except Transaction ID
# Incorrect data types for columns for example they are all strings when price per unit and total spent should be ints/doubles
# Transaction Date contains a placeholder value "UNKONWN" for 159 values

# %%
# Task 2.3
# This data appears as dirty. It has lots of missing data in fields like 'Location' and 'Payment Method'. The data types do not match their
# fields using strings for everything. Finally there is placeholder data in the results masked as 'UNKNOWN'.
